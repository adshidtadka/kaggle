# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-677e5b8b0f88> in <module>()
#       4
#       5 import numpy as np # linear algebra
# ----> 6 import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#       7
#       8 # Input data files are available in the "../input/" directory.
#
# ModuleNotFoundError: No module named 'pandas'

# %%
test = pd.read_csv('../input/test.csv')
train = pd.read_csv('../input/train.csv')

# %%
test.head(10)
# Out:
#         item_id       user_id                   region            city  \
# 0  6544e41a8817  dbe73ad6e4b5    Волгоградская область       Волгоград
# 1  65b9484d670f  2e11806abe57     Свердловская область     Нижняя Тура
# 2  8bab230b2ecd  0b850bbebb10    Новосибирская область          Бердск
# 3  8e348601fefc  5f1d5c3ce0da      Саратовская область         Саратов
# 4  8bd2fe400b89  23e2d97bfc7f     Оренбургская область         Бузулук
# 5  c63dbd6c657f  c2a632af2602       Ростовская область  Ростов-на-Дону
# 6  6d1a410df86e  b239811ad530     Оренбургская область        Оренбург
# 7  e8d3e7922b80  d85fa02e6341  Калининградская область     Калининград
# 8  2bc1ab208462  ae6586719bec    Новосибирская область     Новосибирск
# 9  7e05d77a9181  30ad26d633ef     Свердловская область       Полевской
#
#   parent_category_name               category_name                 param_1  \
# 0          Личные вещи      Детская одежда и обувь           Для мальчиков
# 1        Хобби и отдых                  Велосипеды                Дорожные
# 2  Бытовая электроника               Аудио и видео  Телевизоры и проекторы
# 3      Для дома и дачи             Бытовая техника               Для кухни
# 4          Личные вещи  Товары для детей и игрушки         Детские коляски
# 5      Для дома и дачи      Ремонт и строительство          Окна и балконы
# 6  Бытовая электроника                    Ноутбуки                     NaN
# 7  Бытовая электроника                    Телефоны              Аксессуары
# 8  Бытовая электроника       Товары для компьютера   Флэшки и карты памяти
# 9          Личные вещи      Детская одежда и обувь             Для девочек
#
#           param_2 param_3                                       title  \
# 0           Обувь      25                             Отдам бесплатно
# 1             NaN     NaN                            Продам велосипед
# 2             NaN     NaN                                         BBK
# 3         Вытяжки     NaN                           Вытяжка Jetair 60
# 4             NaN     NaN                           Коляска зима-лето
# 5             NaN     NaN                 Стекла для пластиковых окон
# 6             NaN     NaN  Ноутбук Lenovo Ideapad 300-15Ibr арт.14899
# 7  Чехлы и плёнки     NaN             Nillkin Phenom для Apple iPhone
# 8             NaN     NaN                    Флешка USB 32Gb smartbuy
# 9           Обувь      23                                     Ботинки
#
#                                          description    price  \
# 0                                       На ангарском      NaN
# 1  Продам велосипед KAMA  F200,в нормальном состо...   3000.0
# 2  Продам новый телевизор BBK  32 диагональ смарт...  15000.0
# 3  Продам новую вытяжку в упаковке,с документами....   4500.0
# 4  Продам отличную коляску. б/у 1 год. все вопрос...   4900.0
# 5  Продаю стеклопакеты новые:/\n1. 1322х652х24 /\...    500.0
# 6  Описание: /\nНоутбук Lenovo IdeaPad 300-15IBR ...  20990.0
# 7  Для iPhone 7 (черный)/\n /\nПродаются от магаз...    990.0
# 8  новые/\n /\nесть синие и оранжевые/\n /\nSmart...   1200.0
# 9                                    Фирма "Кенгуру"    400.0
#
#    item_seq_number activation_date user_type  \
# 0               66      2017-04-18   Private
# 1                4      2017-04-16   Private
# 2               15      2017-04-17   Private
# 3               70      2017-04-17   Private
# 4               15      2017-04-15   Private
# 5               39      2017-04-12   Private
# 6            57316      2017-04-17      Shop
# 7              851      2017-04-18      Shop
# 8            10020      2017-04-18   Company
# 9               16      2017-04-12   Private
#
#                                                image  image_top_1
# 0  a8b57acb5ab304f9c331ac7a074219aed4d349d8aef386...       2020.0
# 1                                                NaN          NaN
# 2  8c361112cb049745ef2d1b0ae73594fc5c107286b0c942...       2960.0
# 3                                                NaN          NaN
# 4  bc3cf6deef10840fc302e38eb48fa7748aa1e28d534f8f...       1002.0
# 5  7acdde494d48f4e46c8be158d64ad73a61d153b825c378...       1409.0
# 6  f52abf9f68eca4aac35ed2b67bf093095950c417c080dd...       2961.0
# 7  2e2b5526345f5d66571615dd0fdc984f765a336ec6df3d...       2909.0
# 8  8aa1dfcbdc489750eb965e43ff545505f2c845990d73f9...       2815.0
# 9  4870dbf90fffd7fcbc34ef30cd6c2cf3f2fbe81bc1ef66...         88.0

# %%
test.describe()
# Out:
#               price  item_seq_number    image_top_1
# count  4.778530e+05    508438.000000  465829.000000
# mean   2.798189e+05       825.132150    1297.959228
# std    5.364218e+06      5646.868618     961.065300
# min    0.000000e+00         1.000000       0.000000
# 25%    5.000000e+02         8.000000     467.000000
# 50%    1.500000e+03        30.000000    1132.000000
# 75%    8.600000e+03        94.000000    2218.000000
# max    3.000060e+09    205064.000000    3066.000000

# %%
train.describe(include='all')
# Out:
#              item_id       user_id              region       city  \
# count        1503424       1503424             1503424    1503424
# unique       1503424        771769                  28       1733
# top     14102ba1651e  45ba3f23bf25  Краснодарский край  Краснодар
# freq               1          1080              141416      63638
# mean             NaN           NaN                 NaN        NaN
# std              NaN           NaN                 NaN        NaN
# min              NaN           NaN                 NaN        NaN
# 25%              NaN           NaN                 NaN        NaN
# 50%              NaN           NaN                 NaN        NaN
# 75%              NaN           NaN                 NaN        NaN
# max              NaN           NaN                 NaN        NaN
#
#        parent_category_name              category_name         param_1  \
# count               1503424                    1503424         1441848
# unique                    9                         47             371
# top             Личные вещи  Одежда, обувь, аксессуары  Женская одежда
# freq                 697623                     282753          226289
# mean                    NaN                        NaN             NaN
# std                     NaN                        NaN             NaN
# min                     NaN                        NaN             NaN
# 25%                     NaN                        NaN             NaN
# 50%                     NaN                        NaN             NaN
# 75%                     NaN                        NaN             NaN
# max                     NaN                        NaN             NaN
#
#        param_2   param_3    title          description         price  \
# count   848882    640859  1503424              1387148  1.418062e+06
# unique     271      1219   788377              1317102           NaN
# top      Обувь  Вторичка   Платье  В хорошем состоянии           NaN
# freq    150450     50615    15550                 2249           NaN
# mean       NaN       NaN      NaN                  NaN  3.167081e+05
# std        NaN       NaN      NaN                  NaN  6.689154e+07
# min        NaN       NaN      NaN                  NaN  0.000000e+00
# 25%        NaN       NaN      NaN                  NaN  5.000000e+02
# 50%        NaN       NaN      NaN                  NaN  1.300000e+03
# 75%        NaN       NaN      NaN                  NaN  7.000000e+03
# max        NaN       NaN      NaN                  NaN  7.950101e+10
#
#         item_seq_number activation_date user_type  \
# count      1.503424e+06         1503424   1503424
# unique              NaN              21         3
# top                 NaN      2017-03-20   Private
# freq                NaN          115190   1075706
# mean       7.436740e+02             NaN       NaN
# std        5.572522e+03             NaN       NaN
# min        1.000000e+00             NaN       NaN
# 25%        9.000000e+00             NaN       NaN
# 50%        2.900000e+01             NaN       NaN
# 75%        8.800000e+01             NaN       NaN
# max        2.044290e+05             NaN       NaN
#
#                                                     image   image_top_1  \
# count                                             1390836  1.390836e+06
# unique                                            1390836           NaN
# top     3530ebcf718e02e68d1c2d238e1770f4a9f5725082e8dd...           NaN
# freq                                                    1           NaN
# mean                                                  NaN  1.241932e+03
# std                                                   NaN  9.704641e+02
# min                                                   NaN  0.000000e+00
# 25%                                                   NaN  4.250000e+02
# 50%                                                   NaN  1.057000e+03
# 75%                                                   NaN  2.217000e+03
# max                                                   NaN  3.066000e+03
#
#         deal_probability
# count       1.503424e+06
# unique               NaN
# top                  NaN
# freq                 NaN
# mean        1.391306e-01
# std         2.600785e-01
# min         0.000000e+00
# 25%         0.000000e+00
# 50%         0.000000e+00
# 75%         1.508700e-01
# max         1.000000e+00

# %%
train.shape
# Out:
# (1503424, 18)

# %%
test['is_train'] = False
train['is_train'] = True

all_df = pd.concat([test, train], axis = 0)

# %%
all_df.tail()
# Out:
#         activation_date               category_name       city  \
# 1503419      2017-03-20      Детская одежда и обувь      Пермь
# 1503420      2017-03-28           Предложение услуг  Краснодар
# 1503421      2017-03-21                    Квартиры    Белебей
# 1503422      2017-03-22      Детская одежда и обувь  Березники
# 1503423      2017-03-21  Товары для детей и игрушки      Анапа
#
#          deal_probability                                        description  \
# 1503419           0.25019                                                NaN
# 1503420           0.60000  Произведем бесплатный замер, изготовим и устан...
# 1503421           0.39569  Продам квартиру с отличным ремонтом , две лодж...
# 1503422           0.00000         Продам красивые туфли в хорошем состоянии!
# 1503423           0.00000  ПРЕДЛАГАЕМ ВАШЕМУ ВНИМАНИЮ УНИКАЛЬНЫЕ ИГРУШКИ ...
#
#                                                      image  image_top_1  \
# 1503419  2da79294c6f23f61d4bf6a8f4034f87e2f318b7e32c68b...         88.0
# 1503420  33e13a67b441486ebe48e1459382caa620c4d1802aad1c...       1191.0
# 1503421  2ae822ca21cff9465e430c68a1df31c5cda658cbc00eb1...       1202.0
# 1503422  6b4285c22388a5dae37c3d390d3e1b174f7a980d9e3919...         87.0
# 1503423  87cca5889b96b0368bffbe7cdb3f0cc5fa660f33be9fd0...        979.0
#
#          is_train       item_id  item_seq_number                param_1  \
# 1503419      True  5e6b7f0f3f65                7            Для девочек
# 1503420      True  d1f0910d2126                1  Ремонт, строительство
# 1503421      True  bc04866bc803               50                 Продам
# 1503422      True  f782f2ad9349               33            Для девочек
# 1503423      True  9ad3b7bff1db               18                Игрушки
#
#                  param_2   param_3 parent_category_name   price  \
# 1503419            Обувь        26          Личные вещи   300.0
# 1503420  Ремонт квартиры       NaN               Услуги   200.0
# 1503421                4  Вторичка         Недвижимость     NaN
# 1503422            Обувь        27          Личные вещи   350.0
# 1503423              NaN       NaN          Личные вещи  1500.0
#
#                      region  \
# 1503419       Пермский край
# 1503420  Краснодарский край
# 1503421        Башкортостан
# 1503422       Пермский край
# 1503423  Краснодарский край
#
#                                                      title       user_id  \
# 1503419                                          Ботиночки  dd05217165ea
# 1503420                                   Натяжной потолок  dc23ef451c8a
# 1503421                       4-к квартира, 83 м², 4/5 эт.  66a7016a5995
# 1503422                                      Туфли-балетки  2d3ac1f5a7b3
# 1503423  Кукольные домики из берез. фанеры (большой выбор)  f3342ccd95c8
#
#         user_type
# 1503419   Private
# 1503420   Private
# 1503421   Company
# 1503422   Private
# 1503423   Private

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
le.fit(all_df['item_id'])
# Out:
# LabelEncoder()

# %%
cat_vars = ["user_id", "region", "city", "parent_category_name", "category_name", "param_1", "param_2", "param_3", "user_type"]
for col in cat_vars:
    all_df[col] = all_df[col].astype('str')
    le.fit(all_df[col])
    all_df[col] = le.transform(all_df[col])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b98e85a0abf6> in <module>()
#       1 cat_vars = ["user_id", "region", "city", "parent_category_name", "category_name", "param_1", "param_2", "param_3", "user_type"]
#       2 for col in cat_vars:
# ----> 3     all_df[col] = all_df[col].astype('str')
#       4     le.fit(all_df[col])
#       5     all_df[col] = le.transform(all_df[col])
#
# NameError: name 'all_df' is not defined

# %%
all_df.head()

# %%
cols_to_drop = ["item_id", "title", "description", "activation_date", "image"]
all_df = all_df.drop(cols_to_drop, axis = 1)

# %%
all_df.head()

# %%
all_df = all_df.fillna(0)

# %%
all_df.head()
